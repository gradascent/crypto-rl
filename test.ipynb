# %%
from gymnasium import Env

# %%
# %pip uninstall gym
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install stable-baselines3
# Out:
# ...
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      -------------------------------------- 162.8/162.8 kB 4.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/182.3 kB ? eta -:--:--
#    ---------------------------------------- 182.3/182.3 kB 5.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.7 MB 14.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.1/7.7 MB 14.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.1/7.7 MB 16.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.2/7.7 MB 18.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.5/7.7 MB 20.7 MB/s eta 0:00:01
#    ------------------------------- -------- 6.1/7.7 MB 22.9 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.7 MB 24.0 MB/s eta 0:00:01
# ...
